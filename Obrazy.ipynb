# %% [markdown]
# <a href="https://colab.research.google.com/github/chaosdomok/data-science-bootcamp/blob/main/Obrazy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('bolonia-1.jpg')
img
# Out:
# array([[[  0, 137, 194],
#         [  0, 137, 194],
#         [  0, 137, 194],
#         ...,
#         [  0, 124, 178],
#         [  0, 124, 178],
#         [  0, 124, 178]],
#
#        [[  0, 137, 194],
#         [  0, 137, 194],
#         [  0, 137, 194],
#         ...,
#         [  0, 124, 178],
#         [  0, 124, 178],
#         [  0, 124, 178]],
#
#        [[  0, 137, 194],
#         [  0, 137, 194],
#         [  0, 137, 194],
#         ...,
#         [  0, 124, 178],
#         [  0, 124, 178],
#         [  0, 124, 178]],
#
#        ...,
#
#        [[ 17,   2,   9],
#         [ 15,   0,   7],
#         [ 14,   0,   6],
#         ...,
#         [103,  83,  85],
#         [102,  82,  84],
#         [101,  81,  83]],
#
#        [[ 14,   1,   8],
#         [ 12,   0,   6],
#         [ 11,   0,   5],
#         ...,
#         [104,  84,  86],
#         [103,  83,  85],
#         [102,  82,  84]],
#
#        [[ 13,   0,   7],
#         [ 12,   0,   6],
#         [ 11,   0,   5],
# ...

# %%
img.shape
# Out:
# (1277, 1920, 3)

# %%
plt.imshow(img)
plt.axis('Off')
# Out:
# (-0.5, 1919.5, 1276.5, -0.5)

# %%
fig = plt.figure(figsize=(12, 10))
plt.subplot(221)
plt.imshow(mpimg.imread('bolonia-1.jpg'))
plt.subplot(222)
plt.imshow(mpimg.imread('bolonia-muzea.jpg'))
plt.subplot(223)
plt.imshow(mpimg.imread('Bolonia-Emilia-Romania-Pion-nag.jpg'))

# %%
fig = plt.figure(figsize=(12, 10))

for idx, img in enumerate(['bolonia-1.jpg', 'bolonia-muzea.jpg', 'Bolonia-Emilia-Romania-Pion-nag.jpg']):
  plt.subplot(140 + idx + 1)
  plt.imshow(mpimg.imread(img))
